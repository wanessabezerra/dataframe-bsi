# %% [markdown]
# # Junção dos Dataframes: Turma, Matrícula e Componentes Curriculares

# %% [markdown]
# Esse dataframe é a junção dos dataframes turma, matrícula e componentes curriculares dos discentes de Sistemas de Informação da UFRN, no período de 2009.1 à 2022.2.

# %% [markdown]
# Importando o Pandas e o Csv

# %%
import pandas as pd
import csv

# %% [markdown]
# Leitura dos arquivos em csv e carregamento desses dados em um DataFrame usando o ponto e vírgula como separador.

# %%
dfturma = pd.read_csv('turmas-2009-2022.csv', sep=';')
dfcomponente = pd.read_csv('componentes-curriculares-presenciais.csv', sep=';')
dfmatricula = pd.read_csv('matricula-2009-2022.csv', sep=';')
# Out:
# /tmp/ipykernel_6391/3601441257.py:1: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfturma = pd.read_csv('turmas-2009-2022.csv', sep=';')

# %% [markdown]
# ## Junção dos Dataframes

# %% [markdown]
# Junção do dataframe matrícula com o dataframe turma usando como chave id_turma.

# %%
turma_matricula = pd.merge(dfturma, dfmatricula, on='id_turma', how='inner')
turma_matricula
# Out:
#        id_turma codigo_turma      siape  matricula_docente_externo observacao  \
# 0      57512128          1.0  6350665.0                        NaN        NaN
# 1      57512128          1.0  6350665.0                        NaN        NaN
# 2      57512128          1.0  6350665.0                        NaN        NaN
# 3      57512128          1.0  6350665.0                        NaN        NaN
# 4      57512128          1.0  6350665.0                        NaN        NaN
# ...         ...          ...        ...                        ...        ...
# 60985  57711037          IND  1259912.0                        NaN        NaN
# 60986  57711037          IND  1259912.0                        NaN        NaN
# 60987  57711651          IND  3766151.0                        NaN        NaN
# 60988  57711651          IND  3766151.0                        NaN        NaN
# 60989  57711651          IND  3766151.0                        NaN        NaN
#
#        id_componente_curricular  ch_dedicada_periodo nivel_ensino  \
# 0                       2037000                   90    GRADUAÇÃO
# 1                       2037000                   90    GRADUAÇÃO
# 2                       2037000                   90    GRADUAÇÃO
# 3                       2037000                   90    GRADUAÇÃO
# 4                       2037000                   90    GRADUAÇÃO
# ...                         ...                  ...          ...
# 60985                   2050107                   30    GRADUAÇÃO
# 60986                   2050107                   30    GRADUAÇÃO
# 60987                   2054400                   60    GRADUAÇÃO
# 60988                   2054400                   60    GRADUAÇÃO
# 60989                   2054400                   60    GRADUAÇÃO
#
#        campus_turma      local  ...  agrupadora  id_turma_agrupadora  \
# 0      Campus Caicó       B-09  ...       False                  NaN
# 1      Campus Caicó       B-09  ...       False                  NaN
# 2      Campus Caicó       B-09  ...       False                  NaN
# 3      Campus Caicó       B-09  ...       False                  NaN
# 4      Campus Caicó       B-09  ...       False                  NaN
# ...             ...        ...  ...         ...                  ...
# 60985  Campus Caicó  A definir  ...       False                  NaN
# 60986  Campus Caicó  A definir  ...       False                  NaN
# 60987  Campus Caicó  a definir  ...       False                  NaN
# 60988  Campus Caicó  a definir  ...       False                  NaN
# 60989  Campus Caicó  a definir  ...       False                  NaN
#
#       qtd_aulas_lancadas situacao_turma convenio  modalidade_participantes  \
# 0                    NaN    CONSOLIDADA      NaN                Presencial
# 1                    NaN    CONSOLIDADA      NaN                Presencial
# 2                    NaN    CONSOLIDADA      NaN                Presencial
# 3                    NaN    CONSOLIDADA      NaN                Presencial
# 4                    NaN    CONSOLIDADA      NaN                Presencial
# ...                  ...            ...      ...                       ...
# 60985                0.0    CONSOLIDADA      NaN                Presencial
# 60986                0.0    CONSOLIDADA      NaN                Presencial
# 60987                6.0    CONSOLIDADA      NaN                Presencial
# 60988                6.0    CONSOLIDADA      NaN                Presencial
# 60989                6.0    CONSOLIDADA      NaN                Presencial
#
#                                discente unidade  media_final  descricao
# 0      afba64c0118bfcc8d5b3987e725ed545     1.0          1,5  REPROVADO
# 1      afba64c0118bfcc8d5b3987e725ed545     2.0          1,5  REPROVADO
# 2      afba64c0118bfcc8d5b3987e725ed545     3.0          1,5  REPROVADO
# 3      9526e01da587b20211a39b4e66673aea     1.0          9,2   APROVADO
# 4      9526e01da587b20211a39b4e66673aea     2.0          9,2   APROVADO
# ...                                 ...     ...          ...        ...
# 60985  e10089f6080d3afa8904437086ea2752     2.0          9,3   APROVADO
# 60986  e10089f6080d3afa8904437086ea2752     3.0          9,3   APROVADO
# 60987  943463d2de8c6a60ec5f5d959ba7f1ac     1.0         10,0   APROVADO
# 60988  943463d2de8c6a60ec5f5d959ba7f1ac     2.0         10,0   APROVADO
# 60989  943463d2de8c6a60ec5f5d959ba7f1ac     3.0         10,0   APROVADO
#
# [60990 rows x 30 columns]

# %% [markdown]
# Junção do dataframe turma_matricula com o dataframe componente usando as chaves id_componente_curricular e id_componente.

# %%
turma_matricula_componente = pd.merge(turma_matricula, dfcomponente, left_on="id_componente_curricular", right_on="id_componente", how='inner')
turma_matricula_componente
# Out:
#        id_turma codigo_turma      siape  matricula_docente_externo observacao  \
# 0      57512128          1.0  6350665.0                        NaN        NaN
# 1      57512128          1.0  6350665.0                        NaN        NaN
# 2      57512128          1.0  6350665.0                        NaN        NaN
# 3      57512128          1.0  6350665.0                        NaN        NaN
# 4      57512128          1.0  6350665.0                        NaN        NaN
# ...         ...          ...        ...                        ...        ...
# 60985  57711037          IND  1259912.0                        NaN        NaN
# 60986  57711037          IND  1259912.0                        NaN        NaN
# 60987  57711651          IND  3766151.0                        NaN        NaN
# 60988  57711651          IND  3766151.0                        NaN        NaN
# 60989  57711651          IND  3766151.0                        NaN        NaN
#
#        id_componente_curricular  ch_dedicada_periodo nivel_ensino  \
# 0                       2037000                   90    GRADUAÇÃO
# 1                       2037000                   90    GRADUAÇÃO
# 2                       2037000                   90    GRADUAÇÃO
# 3                       2037000                   90    GRADUAÇÃO
# 4                       2037000                   90    GRADUAÇÃO
# ...                         ...                  ...          ...
# 60985                   2050107                   30    GRADUAÇÃO
# 60986                   2050107                   30    GRADUAÇÃO
# 60987                   2054400                   60    GRADUAÇÃO
# 60988                   2054400                   60    GRADUAÇÃO
# 60989                   2054400                   60    GRADUAÇÃO
#
#        campus_turma      local  ...  \
# 0      Campus Caicó       B-09  ...
# 1      Campus Caicó       B-09  ...
# 2      Campus Caicó       B-09  ...
# 3      Campus Caicó       B-09  ...
# 4      Campus Caicó       B-09  ...
# ...             ...        ...  ...
# 60985  Campus Caicó  A definir  ...
# 60986  Campus Caicó  A definir  ...
# 60987  Campus Caicó  a definir  ...
# 60988  Campus Caicó  a definir  ...
# 60989  Campus Caicó  a definir  ...
#
#                                                   ementa  bibliografia  \
# 0      Algoritmos, programas e linguagens de programa...           NaN
# 1      Algoritmos, programas e linguagens de programa...           NaN
# 2      Algoritmos, programas e linguagens de programa...           NaN
# 3      Algoritmos, programas e linguagens de programa...           NaN
# 4      Algoritmos, programas e linguagens de programa...           NaN
# ...                                                  ...           ...
# 60985  Direito do Trabalho; Legislação do Trabalho; L...           NaN
# 60986  Direito do Trabalho; Legislação do Trabalho; L...           NaN
# 60987  Matemática financeira; Capitalização simples; ...           NaN
# 60988  Matemática financeira; Capitalização simples; ...           NaN
# 60989  Matemática financeira; Capitalização simples; ...           NaN
#
#                                                objetivos  \
# 0      Oferecer aos alunos uma visão geral sobre algo...
# 1      Oferecer aos alunos uma visão geral sobre algo...
# 2      Oferecer aos alunos uma visão geral sobre algo...
# 3      Oferecer aos alunos uma visão geral sobre algo...
# 4      Oferecer aos alunos uma visão geral sobre algo...
# ...                                                  ...
# 60985  Estudar os seguintes temas: Direito do Trabalh...
# 60986  Estudar os seguintes temas: Direito do Trabalh...
# 60987  1. Introduzir o aluno no mundo das finanças, e...
# 60988  1. Introduzir o aluno no mundo das finanças, e...
# 60989  1. Introduzir o aluno no mundo das finanças, e...
#
#                                                 conteudo  \
# 0      \r\n\r\n1.\tUnidade I\r\n1.1.\tNoções de lógic...
# 1      \r\n\r\n1.\tUnidade I\r\n1.1.\tNoções de lógic...
# 2      \r\n\r\n1.\tUnidade I\r\n1.1.\tNoções de lógic...
# 3      \r\n\r\n1.\tUnidade I\r\n1.1.\tNoções de lógic...
# 4      \r\n\r\n1.\tUnidade I\r\n1.1.\tNoções de lógic...
# ...                                                  ...
# 60985  Direito do Trabalho; Legislação do Trabalho; L...
# 60986  Direito do Trabalho; Legislação do Trabalho; L...
# 60987  1. Capitalização simples: cálculo do montante,...
# 60988  1. Capitalização simples: cálculo do montante,...
# 60989  1. Capitalização simples: cálculo do montante,...
#
#                                 competencias_habilidades  \
# 0      Ao final da disciplina espera-se que o aluno s...
# 1      Ao final da disciplina espera-se que o aluno s...
# 2      Ao final da disciplina espera-se que o aluno s...
# 3      Ao final da disciplina espera-se que o aluno s...
# 4      Ao final da disciplina espera-se que o aluno s...
# ...                                                  ...
# 60985                                                NaN
# 60986                                                NaN
# 60987                                                NaN
# 60988                                                NaN
# 60989                                                NaN
#
#                                              referencias  ano_programa  \
# 0      ü\tForbellone, André. Lógica de Programação. A...        2010.0
# 1      ü\tForbellone, André. Lógica de Programação. A...        2010.0
# 2      ü\tForbellone, André. Lógica de Programação. A...        2010.0
# 3      ü\tForbellone, André. Lógica de Programação. A...        2010.0
# 4      ü\tForbellone, André. Lógica de Programação. A...        2010.0
# ...                                                  ...           ...
# 60985                                                NaN        2024.0
# 60986                                                NaN        2024.0
# 60987                                                NaN        2021.0
# 60988                                                NaN        2021.0
# 60989                                                NaN        2021.0
#
#       periodo_programa  modalidade curso_componente
# 0                  2.0  Presencial              NaN
# 1                  2.0  Presencial              NaN
# 2                  2.0  Presencial              NaN
# 3                  2.0  Presencial              NaN
# 4                  2.0  Presencial              NaN
# ...                ...         ...              ...
# 60985              1.0  Presencial              NaN
# 60986              1.0  Presencial              NaN
# 60987              2.0  Presencial              NaN
# 60988              2.0  Presencial              NaN
# 60989              2.0  Presencial              NaN
#
# [60990 rows x 59 columns]

# %% [markdown]
# ### Limpeza de dados duplicados

# %%
turma_matricula_componente_limpo = turma_matricula_componente.sort_values(['discente','unidade', 'media_final', 'descricao', 'ano', 'id_componente', 'nome']).drop_duplicates(subset=['discente', 'unidade', 'media_final', 'descricao', 'ano', 'id_componente', 'nome'])
turma_matricula_componente_limpo
# Out:
#        id_turma codigo_turma      siape  matricula_docente_externo  \
# 53645  57678929           01  3766151.0                        NaN
# 60148  57708933           01  2364748.0                        NaN
# 58456  57699493           01  3766151.0                        NaN
# 48560  57662868           01  1100806.0                        NaN
# 39686  57620123           03  1209872.0                        NaN
# ...         ...          ...        ...                        ...
# 9173    1178438           01  1804944.0                        NaN
# 10327   1178453           01  2766151.0                        NaN
# 9021    1178437           01  1687186.0                        NaN
# 9174    1178438           01  1804944.0                        NaN
# 10328   1178453           01  2766151.0                        NaN
#
#                               observacao  id_componente_curricular  \
# 53645                                NaN                     70811
# 60148                                NaN                     62802
# 58456  Todas as aulas serão presenciais.                     70811
# 48560                                NaN                     71950
# 39686                                NaN                     62768
# ...                                  ...                       ...
# 9173                                 NaN                   2037001
# 10327                                NaN                   2037004
# 9021                                 NaN                   2037000
# 9174                                 NaN                   2037001
# 10328                                NaN                   2037004
#
#        ch_dedicada_periodo nivel_ensino  campus_turma  \
# 53645                   60    GRADUAÇÃO  Campus Caicó
# 60148                   60    GRADUAÇÃO  Campus Caicó
# 58456                   60    GRADUAÇÃO  Campus Caicó
# 48560                   60    GRADUAÇÃO  Campus Caicó
# 39686                   60    GRADUAÇÃO  Campus Caicó
# ...                    ...          ...           ...
# 9173                    60    GRADUAÇÃO  Campus Caicó
# 10327                   60    GRADUAÇÃO  Campus Caicó
# 9021                    90    GRADUAÇÃO  Campus Caicó
# 9174                    60    GRADUAÇÃO  Campus Caicó
# 10328                   60    GRADUAÇÃO  Campus Caicó
#
#                                                local  ...  \
# 53645                         Online - Ensino Remoto  ...
# 60148  Laboratório II (John von Neumann) - Bloco BSI  ...
# 58456                                       Sala B04  ...
# 48560                                         Online  ...
# 39686                                        Lab. II  ...
# ...                                              ...  ...
# 9173                                            B-09  ...
# 10327                                           B-09  ...
# 9021                                 LAB.ALAN TURING  ...
# 9174                                            B-09  ...
# 10328                                           B-09  ...
#
#                                                   ementa  bibliografia  \
# 53645  Estudo dos conceitos de inovação, seus reflexo...           NaN
# 60148  Logística e problemas de otimização. Formulaçã...           NaN
# 58456  Estudo dos conceitos de inovação, seus reflexo...           NaN
# 48560  O conceito de Marketing. Conceito e evolução d...           NaN
# 39686  Conceituação de computação móvel, ubíqua e per...           NaN
# ...                                                  ...           ...
# 9173   Definição e origem do termo informática. Eleme...           NaN
# 10327  O conceito de Administração. A evolução das es...           NaN
# 9021   Algoritmos, programas e linguagens de programa...           NaN
# 9174   Definição e origem do termo informática. Eleme...           NaN
# 10328  O conceito de Administração. A evolução das es...           NaN
#
#                                                objetivos  \
# 53645  Estudo dos conceitos de inovação, seus reflexo...
# 60148  Apresentar aos alunos da área de Computação e ...
# 58456  Estudo dos conceitos de inovação, seus reflexo...
# 48560  Apresentar os conceitos fundamentais e prática...
# 39686  1. Apresentar os principais conceitos relativo...
# ...                                                  ...
# 9173   \r\n\tEntender o hardware de um sistema compu...
# 10327  1. Objetivo Geral\r\nDesenvolver o senso críti...
# 9021   Oferecer aos alunos uma visão geral sobre algo...
# 9174   \r\n\tEntender o hardware de um sistema compu...
# 10328  1. Objetivo Geral\r\nDesenvolver o senso críti...
#
#                                                 conteudo  \
# 53645  Estudo dos conceitos de inovação, seus reflexo...
# 60148  1. Introdução à Logística e aos problemas de o...
# 58456  Estudo dos conceitos de inovação, seus reflexo...
# 48560  1ª UNIDADE\r\n1. Visão geral de Marketing (con...
# 39686  1. DISPOSITIVOS MÓVEIS: Conceitos, tipos e car...
# ...                                                  ...
# 9173   \r\n\tHistórico\r\n\tTecnologias e aplicaçõe...
# 10327  1. ABORDAGEM CLÁSSICA DA ADMINISTRAÇÃO\r\n Te...
# 9021   \r\n\r\n1.\tUnidade I\r\n1.1.\tNoções de lógic...
# 9174   \r\n\tHistórico\r\n\tTecnologias e aplicaçõe...
# 10328  1. ABORDAGEM CLÁSSICA DA ADMINISTRAÇÃO\r\n Te...
#
#                                 competencias_habilidades  \
# 53645                                                NaN
# 60148                                                NaN
# 58456                                                NaN
# 48560                                                NaN
# 39686                                                NaN
# ...                                                  ...
# 9173   \r\nAo final do componente curricular o aluno ...
# 10327  Espera-se que o aluno desenvolva o  embasament...
# 9021   Ao final da disciplina espera-se que o aluno s...
# 9174   \r\nAo final do componente curricular o aluno ...
# 10328  Espera-se que o aluno desenvolva o  embasament...
#
#                                              referencias  ano_programa  \
# 53645                                                NaN        2023.0
# 60148                                                NaN        2022.0
# 58456                                                NaN        2023.0
# 48560                                                NaN        2023.0
# 39686                                                NaN        2021.0
# ...                                                  ...           ...
# 9173   \r\nCaro Usuário,\r\n\r\nEstas informações ser...        2013.0
# 10327  Bibliografia Básica\r\nCHIAVENATO, Idalberto. ...        2010.0
# 9021   ü\tForbellone, André. Lógica de Programação. A...        2010.0
# 9174   \r\nCaro Usuário,\r\n\r\nEstas informações ser...        2013.0
# 10328  Bibliografia Básica\r\nCHIAVENATO, Idalberto. ...        2010.0
#
#       periodo_programa  modalidade        curso_componente
# 53645              2.0  Presencial                     NaN
# 60148              2.0  Presencial                     NaN
# 58456              2.0  Presencial                     NaN
# 48560              1.0  Presencial                     NaN
# 39686              2.0  Presencial                     NaN
# ...                ...         ...                     ...
# 9173               2.0  Presencial  SISTEMAS DE INFORMAÇÃO
# 10327              1.0  Presencial                     NaN
# 9021               2.0  Presencial                     NaN
# 9174               2.0  Presencial  SISTEMAS DE INFORMAÇÃO
# 10328              1.0  Presencial                     NaN
#
# [55034 rows x 59 columns]

# %% [markdown]
# ## Tratamento de dados

# %%
dados_turma_matricula_componente = turma_matricula_componente_limpo .replace({'nome':
               {'METODOLOGIA DO TRABALHO CIENTIFICO':'METODOLOGIA DO TRABALHO CIENTIFICO',
                'ALGORITMOS E LÃ“GICA DE PROGRAMAÃ‡ÃƒO':'ALGORITMOS E LOGICA DE PROGRAMACAO',
                'FUNDAMENTOS DE SISTEMAS DE INFORMAÃ‡ÃƒO':'FUNDAMENTOS DE SISTEMAS DE INFORMACAO',
                'INTRODUÃ‡ÃƒO Ã€ INFORMÃTICA':'INTRODUCAO A INFORMATICA',
                'PROGRAMAÃ‡ÃƒO ORIENTADA A OBJETOS I':'PROGRAMACAO ORIENTADA A OBJETOS I',
                'LÃ“GICA':'LOGICA',
                'ÃLGEBRA LINEAR':'ALGEBRA LINEAR',
                'TEORIA GERAL DA ADMINISTRAÃ‡ÃƒO':'TEORIA GERAL DA ADMINISTRACAO',
                'ORGANIZAÃ‡ÃƒO. SISTEMAS E MÃ‰TODOS':'ORGANIZACAO, SISTEMAS E METODOS',
                'LEITURA E PRODUÃ‡ÃƒO DE TEXTO':'LEITURA E PRODUCAO DE TEXTO',
                'INGLÃŠS TÃ‰CNICO':'INGLES TECNICO',
                'PROGRAMAÃ‡ÃƒO ORIENTADA A OBJETOS II':'PROGRAMACAO ORIENTADA A OBJETOS II',
                'CÃLCULO DIFERENCIAL E INTEGRAL':'CALCULO DIFERENCIAL E INTEGRAL',
                'PROBABILIDADE E ESTATÃSTICA':'PROBABILIDADE E ESTATISTICA',
                'PROGRAMAÃ‡ÃƒO':'PROGRAMACAO',
                'PROGRAMAÃ‡ÃƒO WEB':'PROGRAMACAO WEB',
                'PROJETO E ADMINISTRAÃ‡ÃƒO DE BANCO DE DADOS':'PROJETO E ADMINISTRACAO DE BANCO DE DADOS',
                'TÃ“PICOS EM SISTEMAS DE INFORMAÃ‡ÃƒO':'TOPICOS EM SISTEMAS DE INFORMACAO',
                'FUNDAMENTOS DO DIREITO E LEGISLAÃ‡ÃƒO DIGITAL':'FUNDAMENTOS DO DIREITO E LEGISLACAO DIGITAL',
                'APRENDIZADO DE MÃQUINA':'APRENDIZADO DE MAQUINA',
                'GESTÃƒO DE PROJETO DE SOFTWARE':'GESTAO DE PROJETO DE SOFTWARE',
                'AUDITORIA E SEGURANÃ‡A DE SISTEMAS DE INFORMAÃ‡ÃƒO':'AUDITORIA E SEGURANCA DE SISTEMAS DE INFORMACAO',
                'MINERAÃ‡ÃƒO DE DADOS':'MINERACAO DE DADOS',
                'INTERAÃ‡ÃƒO HUMANO-COMPUTADOR':'INTERACAO HUMANO-COMPUTADOR',
                'Ã‰TICA':'ETICA',
                'MATEMÃTICA FINANCEIRA':'MATEMATICA FINANCEIRA',
                'SISTEMAS DISTRIBUÃDOS':'SISTEMAS DISTRIBUIDOS',
                'DIREITO E LEGISLAÃ‡ÃƒO SOCIAL':'DIREITO E LEGISLACAO SOCIAL',
                'Ã‰TICA GERAL E PROFISSIONAL':'ETICA GERAL E PROFISSIONAL',
                'TÃ“PICOS ESPECIAIS ENGENHARIA DE SOFTWARE':'TOPICOS ESPECIAIS ENGENHARIA DE SOFTWARE',
                'PROGRAMAÃ‡ÃƒO VISUAL':'PROGRAMACAO VISUAL',
                'LÃNGUA BRASILEIRA DE SINAIS - LIBRAS':'LINGUA BRASILEIRA DE SINAIS - LIBRAS',
                'TÃ“PICOS AVANÃ‡ADOS EM PROGRAMAÃ‡ÃƒO':'TOPICOS AVANCADOS EM PROGRAMACAO',
                'GESTÃƒO DA INFORMAÃ‡ÃƒO E DOS SISTEMAS DE INFORMAÃ‡ÃƒO':'GESTAO DA INFORMACAO E DOS SISTEMAS DE INFORMACAO',
                'ADMINISTRAÃ‡ÃƒO DE SERVIDORES DE REDE':'ADMINISTRACAO DE SERVIDORES DE REDE',
                'PROGRAMAÃ‡ÃƒO PARA DISPOSITIVOS MÃ“VEIS':'PROGRAMACAO PARA DISPOSITIVOS MOVEIS',
                'HISTÃ“RIA DA ÃFRICA E DOS AFRO-BRASILEIROS':'HISTORIA DA AFRICA E DOS AFRO-BRASILEIROS',
                'ORÃ‡AMENTO EMPRESARIAL':'ORCAMENTO EMPRESARIAL',
                'INTRODUÃ‡ÃƒO Ã€ ECONOMIA':'INTRODUCAO A ECONOMIA',
                'ESTUDOS HISTÃ“RICO-FILOSÃ“FICOS DA EDUCAÃ‡ÃƒO':'ESTUDOS HISTORICO-FILOSOFICOS DA EDUCACAO',
                'SEMINÃRIOS DE EDUCAÃ‡ÃƒO INTEGRAL':'SEMINARIOS DE EDUCACAO INTEGRAL',
                'MOVIMENTOS SOCIAIS E EDUCAÃ‡ÃƒO POPULAR':'MOVIMENTOS SOCIAIS E EDUCACAO POPULAR',
                'TÃ“PICOS ESPECIAIS EM BANCOS DE DADOS':'TOPICOS ESPECIAIS EM BANCOS DE DADOS',
                'EMPREENDEDORISMO EM INFORMÃTICA':'EMPREENDEDORISMO EM INFORMATICA',
                'HISTÃ“RIA E MEMÃ“RIA':'HISTORIA E MEMORIA',
                'GESTÃƒO DA INOVAÃ‡ÃƒO':'GESTAO DA INOVACAO',
                'GOVERNANÃ‡A DE TECNOLOGIA DA INFORMAÃ‡ÃƒO':'GOVERNANCA DE TECNOLOGIA DA INFORMACAO',
                'INTELIGÃŠNCIA ARTIFICIAL':'INTELIGENCIA ARTIFICIAL',
                'TÃ“PICOS ESPECIAIS EM CIÃŠNCIA E PRODUÃ‡ÃƒO DE CONHECIMENTO':'TOPICOS ESPECIAIS EM CIENCIA E PRODUCAO DE CONHECIMENTO',
                'TÃ“PICOS AVANÃ‡ADOS EM PROGRAMAÃ‡ÃƒO I':'TOPICOS AVANCADOS EM PROGRAMACAO I',
                'TÃ“PICOS AVANÃ‡ADOS EM PROGRAMAÃ‡ÃƒO II':'TOPICOS AVANCADOS EM PROGRAMACAO II',
                'TÃ“PICOS AVANÃ‡ADOS EM PROGRAMAÃ‡ÃƒO III':'TOPICOS AVANCADOS EM PROGRAMACAO III',
                'INTELIGÃŠNCIA COMPUTACIONAL':'INTELIGENCIA COMPUTACIONAL',
                'GERÃŠNCIA DE REDES':'GERENCIA DE REDES',
                'MINERAÃ‡ÃƒO DE DADOS':'MINERACAO DE DADOS',
                'ADMINISTRAÃ‡ÃƒO DE SERVIDORES DE REDE':'ADMINISTRACAO DE SERVIDORES DE REDE',
                'SISTEMAS DE APOIO Ã€ DECISÃƒO':'SISTEMAS DE APOIO A DECISAO',
                'PROBABILIDADE E ESTATÃSTICA':'PROBABILIDADE E ESTATISTICA',
                'NOÃ‡Ã•ES DE ELETRÃ”NICA DIGITAL E PROGRAMACAO DE MICROCONTROLADORES':'NOCOES DE ELETRONICA DIGITAL E PROGRAMACAO DE MICROCONTROLADORES',
                'FUNDAMENTOS DE MATEMÃTICA':'FUNDAMENTOS DE MATEMATICA',
                'ESTRUTURA DE DADOS':'ESTRUTURA DE DADOS',
                'ESTRUTURAS DE DADOS':'ESTRUTURA DE DADOS',
                'FILOSOFIA I':'FILOSOFIA I',
                'BANCO DE DADOS':'BANCO DE DADOS',
                'ARQUITETURA DE COMPUTADORES':'ARQUITETURA DE COMPUTADORES',
                'TEORIA GERAL DOS SISTEMAS':'TEORIA GERAL DOS SISTEMAS',
                'SISTEMAS OPERACIONAIS':'SISTEMAS OPERACIONAIS',
                'ENGENHARIA DE SOFTWARE II':'ENGENHARIA DE SOFTWARE II',
                'ENGENHARIA DE SOFTWARE I':'ENGENHARIA DE SOFTWARE I',
                'GEOMETRIA ANALÃTICA':'GEOMETRIA ANALITICA',
                'REDES DE COMPUTADORES':'REDES DE COMPUTADORES',
                'MATEMATICA PARA CIENCIAS CONTABEIS':'MATEMATICA PARA CIENCIAS CONTABEIS',
                'CLOUD COMPUTING':'CLOUD COMPUTING',
                'SOCIOLOGIA ORGANIZACIONAL':'SOCIOLOGIA ORGANIZACIONAL',
                'GEOMETRIA ESPACIAL':'GEOMETRIA ESPACIAL',
                'MULTIMÃDIA NA EDUCAÃ‡ÃƒO':'MULTIMIDIA NA EDUCACAO',
                'SOCIOLOGIA GERAL E JURÃDICA':'SOCIOLOGIA GERAL E JURIDICA',
                'FERRAMENTAS COMPUTACIONAIS DE ENS.DE MATEMÃTICA':'FERRAMENTAS COMPUTACIONAIS DE ENS.DE MATEMATICA',
                'TÃ“PICOS ESPECIAIS EM SEGURANÃ‡A DA INFORMAÃ‡ÃƒO  I':'TOPICOS ESPECIAIS EM SEGURANCA DA INFORMACAO I',
                'TÃ“PICOS ESPECIAIS EM INFORMÃTICA NA EDUCAÃ‡ÃƒO':'TOPICOS ESPECIAIS EM INFORMATICA NA EDUCACAO',
                'PARADIGMAS DE LINGUAGENS DE PROGRAMAÃ‡ÃƒO':'PARADIGMAS DE LINGUAGENS DE PROGRAMACAO',
                'SISTEMAS DISTRIBUÃDOS':'CLOUD COMPUTING',
                'SOCIOLOGIA ORGANIZACIONAL':'SOCIOLOGIA ORGANIZACIONAL',
                'TÃ“PICOS ESPECIAIS EM SISTEMAS DE INFORMAÃ‡ÃƒO III':'TOPICOS ESPECIAIS EM SISTEMAS DE INFORMACAO III',
                'EDUCAÃ‡ÃƒO Ã‰TNICO-RACIAL':'EDUCACAO ETNICO-RACIAL',
                'CONTABILIDADE E CUSTOS':'CONTABILIDADE E CUSTOS',
                'PESQUISA OPERACIONAL':'PESQUISA OPERACIONAL',
                'TÃ“PICOS ESPECIAIS ENGENHARIA DE SOFTWARE I':'TOPICOS ESPECIAIS ENGENHARIA DE SOFTWARE I',
                'SEMINÃRIO DE TECNOLOGIA DA INFORMAÃ‡ÃƒO':'SEMINARIO DE TECNOLOGIA DA INFORMACAO',
                'CONTABILIDADE AMBIENTAL':'CONTABILIDADE AMBIENTAL',
                'TESTE DE SOFTWARE':'TESTE DE SOFTWARE',
                'MARKETING DIGITAL':'MARKETING DIGITAL',
                'INTRODUÃ‡ÃƒO Ã€ INTERNET DAS COISAS':'INTRODUCAO A INTERNET DAS COISAS',
                'TÃ“PICOS ESPECIAIS EM MATEMÃTICA COMPUTACIONAL':'TOPICOS ESPECIAIS EM MATEMATICA COMPUTACIONAL',
                'METODOLOGIA CIENTÃFICA':'METODOLOGIA CIENTIFICA',
                'PRÃTICA DE LEITURA E PRODUCAO DE TEXTOS':'PRATICA DE LEITURA E PRODUCAO DE TEXTOS',
                'EMPREENDENDORISMO EM INFORMÃTICA':'EMPREENDENDORISMO EM INFORMATICA',
                'INTRODUÃ‡ÃƒO Ã€ INTERNET DAS COISAS':'INTRODUCAO A INTERNET DAS COISAS',
                'MATEMÃTICA BÃSICA':'MATEMATICA BASICA',
                'GEOGRAFIA FÃSICA DO BRASIL':'GEOGRAFIA FISICA DO BRASIL',
                'SEMINÃRIO DO TCC':'SEMINARIO DO TCC',
                'TÃ“PICOS AVANÃ‡ADOS EM PROGRAMACAO':'TOPICOS AVANCADOS EM PROGRAMACAO',
                'HISTÃ“RIA DO RIO GRANDE DO NORTE I':'HISTORIA DO RIO GRANDE DO NORTE I',
                'CONTABILIDADE BÃSICA I':'CONTABILIDADE BASICA I',
                'METODOLOGIA DO TRABALHO CIENTÃFICO':'METODOLOGIA DO TRABALHO CIENTIFICO',
                'SEMINÃRIO DE GEOGRAFIA DA AMÃ‰RICA LATINA':'SEMINARIO DE GEOGRAFIA DA AMERICA LATINA',
                'METODOLOGIA DA PESQUISA CIENTÃFICA':'METODOLOGIA DA PESQUISA CIENTIFICA',
                'TÃ“PICOS ESPECIAIS EM SISTEMAS DE INFORMAÃ‡ÃƒO II':'TOPICOS ESPECIAIS EM SISTEMAS DE INFORMACAO II',
                'MÃ‰TODOS E TÃ‰CNICAS DE PESQUISA CIENTÃFICA':'METODOS E TECNICAS DE PESQUISA CIENTIFICA',
                'METODOLOGIA DE ENSINO NA ÃREA DE DEFICIÃŠNCIA AUDITIVA':'METODOLOGIA DE ENSINO NA AREA DE DEFICIENCIA AUDITIVA',
                'HISTÃ“RIA MEDIEVAL I':'HISTORIA MEDIEVAL I',
                'CLIMATOLOGIA SISTEMÃTICA E REGIONAL':'CLIMATOLOGIA SISTEMITICA E REGIONAL',
                'LÃNGUA DE SINAIS BRASILEIRA  - LIBRAS':'LINGUA DE SINAIS BRASILEIRA  - LIBRAS',
                'HISTÃ“RIA DA AMÃ‰RICA I':'HISTORIA DA AMERICA I',
                'INTRODUÃ‡ÃƒO A PESQUISA HISTÃ“RICA':'INTRODUCAO A PESQUISA HISTORICA',
                'ECONOMIA POLÃTICA':'ECONOMIA POLITICA',
                'INTRODUÃ‡ÃƒO Ã€ LOGICA MATEMÃTICA':'INTRODUCAO A LOGICA MATEMATICA',
                }}, regex=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 dados_turma_matricula_componente = turma_matricula_componente_limpo .replace({'nome':
#       2                {'METODOLOGIA DO TRABALHO CIENTIFICO':'METODOLOGIA DO TRABALHO CIENTIFICO',
#       3                 'ALGORITMOS E LÃ“GICA DE PROGRAMAÃ‡ÃƒO':'ALGORITMOS E LOGICA DE PROGRAMACAO',
#       4                 'FUNDAMENTOS DE SISTEMAS DE INFORMAÃ‡ÃƒO':'FUNDAMENTOS DE SISTEMAS DE INFORMACAO',
#       5                 'INTRODUÃ‡ÃƒO Ã€ INFORMÃTICA':'INTRODUCAO A INFORMATICA',
#       6                 'PROGRAMAÃ‡ÃƒO ORIENTADA A OBJETOS I':'PROGRAMACAO ORIENTADA A OBJETOS I',
#       7                 'LÃ“GICA':'LOGICA',
#       8                 'ÃLGEBRA LINEAR':'ALGEBRA LINEAR',
#       9                 'TEORIA GERAL DA ADMINISTRAÃ‡ÃƒO':'TEORIA GERAL DA ADMINISTRACAO',
#      10                 'ORGANIZAÃ‡ÃƒO. SISTEMAS E MÃ‰TODOS':'ORGANIZACAO, SISTEMAS E METODOS',
#      11                 'LEITURA E PRODUÃ‡ÃƒO DE TEXTO':'LEITURA E PRODUCAO DE TEXTO',
#      12                 'INGLÃŠS TÃ‰CNICO':'INGLES TECNICO',
#      13                 'PROGRAMAÃ‡ÃƒO ORIENTADA A OBJETOS II':'PROGRAMACAO ORIENTADA A OBJETOS II',
#      14                 'CÃLCULO DIFERENCIAL E INTEGRAL':'CALCULO DIFERENCIAL E INTEGRAL',
#      15                 'PROBABILIDADE E ESTATÃSTICA':'PROBABILIDADE E ESTATISTICA',
#      16                 'PROGRAMAÃ‡ÃƒO':'PROGRAMACAO',
#      17                 'PROGRAMAÃ‡ÃƒO WEB':'PROGRAMACAO WEB',
#      18                 'PROJETO E ADMINISTRAÃ‡ÃƒO DE BANCO DE DADOS':'PROJETO E ADMINISTRACAO DE BANCO DE DADOS',
#      19                 'TÃ“PICOS EM SISTEMAS DE INFORMAÃ‡ÃƒO':'TOPICOS EM SISTEMAS DE INFORMACAO',
#      20                 'FUNDAMENTOS DO DIREITO E LEGISLAÃ‡ÃƒO DIGITAL':'FUNDAMENTOS DO DIREITO E LEGISLACAO DIGITAL',
#      21                 'APRENDIZADO DE MÃQUINA':'APRENDIZADO DE MAQUINA',
#      22                 'GESTÃƒO DE PROJETO DE SOFTWARE':'GESTAO DE PROJETO DE SOFTWARE',
#      23                 'AUDITORIA E SEGURANÃ‡A DE SISTEMAS DE INFORMAÃ‡ÃƒO':'AUDITORIA E SEGURANCA DE SISTEMAS DE INFORMACAO',
#      24                 'MINERAÃ‡ÃƒO DE DADOS':'MINERACAO DE DADOS',
#      25                 'INTERAÃ‡ÃƒO HUMANO-COMPUTADOR':'INTERACAO HUMANO-COMPUTADOR',
#      26                 'Ã‰TICA':'ETICA',
#      27                 'MATEMÃTICA FINANCEIRA':'MATEMATICA FINANCEIRA',
#      28                 'SISTEMAS DISTRIBUÃDOS':'SISTEMAS DISTRIBUIDOS',
#      29                 'DIREITO E LEGISLAÃ‡ÃƒO SOCIAL':'DIREITO E LEGISLACAO SOCIAL',
#      30                 'Ã‰TICA GERAL E PROFISSIONAL':'ETICA GERAL E PROFISSIONAL',
#      31                 'TÃ“PICOS ESPECIAIS ENGENHARIA DE SOFTWARE':'TOPICOS ESPECIAIS ENGENHARIA DE SOFTWARE',
#      32                 'PROGRAMAÃ‡ÃƒO VISUAL':'PROGRAMACAO VISUAL',
#      33                 'LÃNGUA BRASILEIRA DE SINAIS - LIBRAS':'LINGUA BRASILEIRA DE SINAIS - LIBRAS',
#      34                 'TÃ“PICOS AVANÃ‡ADOS EM PROGRAMAÃ‡ÃƒO':'TOPICOS AVANCADOS EM PROGRAMACAO',
#      35                 'GESTÃƒO DA INFORMAÃ‡ÃƒO E DOS SISTEMAS DE INFORMAÃ‡ÃƒO':'GESTAO DA INFORMACAO E DOS SISTEMAS DE INFORMACAO',
#      36                 'ADMINISTRAÃ‡ÃƒO DE SERVIDORES DE REDE':'ADMINISTRACAO DE SERVIDORES DE REDE',
#      37                 'PROGRAMAÃ‡ÃƒO PARA DISPOSITIVOS MÃ“VEIS':'PROGRAMACAO PARA DISPOSITIVOS MOVEIS',
#      38                 'HISTÃ“RIA DA ÃFRICA E DOS AFRO-BRASILEIROS':'HISTORIA DA AFRICA E DOS AFRO-BRASILEIROS',
#      39                 'ORÃ‡AMENTO EMPRESARIAL':'ORCAMENTO EMPRESARIAL',
#      40                 'INTRODUÃ‡ÃƒO Ã€ ECONOMIA':'INTRODUCAO A ECONOMIA',
#      41                 'ESTUDOS HISTÃ“RICO-FILOSÃ“FICOS DA EDUCAÃ‡ÃƒO':'ESTUDOS HISTORICO-FILOSOFICOS DA EDUCACAO',
#      42                 'SEMINÃRIOS DE EDUCAÃ‡ÃƒO INTEGRAL':'SEMINARIOS DE EDUCACAO INTEGRAL',
#      43                 'MOVIMENTOS SOCIAIS E EDUCAÃ‡ÃƒO POPULAR':'MOVIMENTOS SOCIAIS E EDUCACAO POPULAR',
#      44                 'TÃ“PICOS ESPECIAIS EM BANCOS DE DADOS':'TOPICOS ESPECIAIS EM BANCOS DE DADOS',
#      45                 'EMPREENDEDORISMO EM INFORMÃTICA':'EMPREENDEDORISMO EM INFORMATICA',
#      46                 'HISTÃ“RIA E MEMÃ“RIA':'HISTORIA E MEMORIA',
#      47                 'GESTÃƒO DA INOVAÃ‡ÃƒO':'GESTAO DA INOVACAO',
#      48                 'GOVERNANÃ‡A DE TECNOLOGIA DA INFORMAÃ‡ÃƒO':'GOVERNANCA DE TECNOLOGIA DA INFORMACAO',
#      49                 'INTELIGÃŠNCIA ARTIFICIAL':'INTELIGENCIA ARTIFICIAL',
#      50                 'TÃ“PICOS ESPECIAIS EM CIÃŠNCIA E PRODUÃ‡ÃƒO DE CONHECIMENTO':'TOPICOS ESPECIAIS EM CIENCIA E PRODUCAO DE CONHECIMENTO',
#      51                 'TÃ“PICOS AVANÃ‡ADOS EM PROGRAMAÃ‡ÃƒO I':'TOPICOS AVANCADOS EM PROGRAMACAO I',
#      52                 'TÃ“PICOS AVANÃ‡ADOS EM PROGRAMAÃ‡ÃƒO II':'TOPICOS AVANCADOS EM PROGRAMACAO II',
#      53                 'TÃ“PICOS AVANÃ‡ADOS EM PROGRAMAÃ‡ÃƒO III':'TOPICOS AVANCADOS EM PROGRAMACAO III',
#      54                 'INTELIGÃŠNCIA COMPUTACIONAL':'INTELIGENCIA COMPUTACIONAL',
#      55                 'GERÃŠNCIA DE REDES':'GERENCIA DE REDES',
#      56                 'MINERAÃ‡ÃƒO DE DADOS':'MINERACAO DE DADOS',
#      57                 'ADMINISTRAÃ‡ÃƒO DE SERVIDORES DE REDE':'ADMINISTRACAO DE SERVIDORES DE REDE',
#      58                 'SISTEMAS DE APOIO Ã€ DECISÃƒO':'SISTEMAS DE APOIO A DECISAO',
#      59                 'PROBABILIDADE E ESTATÃSTICA':'PROBABILIDADE E ESTATISTICA',
#      60                 'NOÃ‡Ã•ES DE ELETRÃ”NICA DIGITAL E PROGRAMACAO DE MICROCONTROLADORES':'NOCOES DE ELETRONICA DIGITAL E PROGRAMACAO DE MICROCONTROLADORES',
#      61                 'FUNDAMENTOS DE MATEMÃTICA':'FUNDAMENTOS DE MATEMATICA',
#      62                 'ESTRUTURA DE DADOS':'ESTRUTURA DE DADOS',
#      63                 'ESTRUTURAS DE DADOS':'ESTRUTURA DE DADOS',
#      64                 'FILOSOFIA I':'FILOSOFIA I',
#      65                 'BANCO DE DADOS':'BANCO DE DADOS',
#      66                 'ARQUITETURA DE COMPUTADORES':'ARQUITETURA DE COMPUTADORES',
#      67                 'TEORIA GERAL DOS SISTEMAS':'TEORIA GERAL DOS SISTEMAS',
#      68                 'SISTEMAS OPERACIONAIS':'SISTEMAS OPERACIONAIS',
#      69                 'ENGENHARIA DE SOFTWARE II':'ENGENHARIA DE SOFTWARE II',
#      70                 'ENGENHARIA DE SOFTWARE I':'ENGENHARIA DE SOFTWARE I',
#      71                 'GEOMETRIA ANALÃTICA':'GEOMETRIA ANALITICA',
#      72                 'REDES DE COMPUTADORES':'REDES DE COMPUTADORES',
#      73                 'MATEMATICA PARA CIENCIAS CONTABEIS':'MATEMATICA PARA CIENCIAS CONTABEIS',
#      74                 'CLOUD COMPUTING':'CLOUD COMPUTING',
#      75                 'SOCIOLOGIA ORGANIZACIONAL':'SOCIOLOGIA ORGANIZACIONAL',
#      76                 'GEOMETRIA ESPACIAL':'GEOMETRIA ESPACIAL',
#      77                 'MULTIMÃDIA NA EDUCAÃ‡ÃƒO':'MULTIMIDIA NA EDUCACAO',
#      78                 'SOCIOLOGIA GERAL E JURÃDICA':'SOCIOLOGIA GERAL E JURIDICA',
#      79                 'FERRAMENTAS COMPUTACIONAIS DE ENS.DE MATEMÃTICA':'FERRAMENTAS COMPUTACIONAIS DE ENS.DE MATEMATICA',
#      80                 'TÃ“PICOS ESPECIAIS EM SEGURANÃ‡A DA INFORMAÃ‡ÃƒO  I':'TOPICOS ESPECIAIS EM SEGURANCA DA INFORMACAO I',
#      81                 'TÃ“PICOS ESPECIAIS EM INFORMÃTICA NA EDUCAÃ‡ÃƒO':'TOPICOS ESPECIAIS EM INFORMATICA NA EDUCACAO',
#      82                 'PARADIGMAS DE LINGUAGENS DE PROGRAMAÃ‡ÃƒO':'PARADIGMAS DE LINGUAGENS DE PROGRAMACAO',
#      83                 'SISTEMAS DISTRIBUÃDOS':'CLOUD COMPUTING',
#      84                 'SOCIOLOGIA ORGANIZACIONAL':'SOCIOLOGIA ORGANIZACIONAL',
#      85                 'TÃ“PICOS ESPECIAIS EM SISTEMAS DE INFORMAÃ‡ÃƒO III':'TOPICOS ESPECIAIS EM SISTEMAS DE INFORMACAO III',
#      86                 'EDUCAÃ‡ÃƒO Ã‰TNICO-RACIAL':'EDUCACAO ETNICO-RACIAL',
#      87                 'CONTABILIDADE E CUSTOS':'CONTABILIDADE E CUSTOS',
#      88                 'PESQUISA OPERACIONAL':'PESQUISA OPERACIONAL',
#      89                 'TÃ“PICOS ESPECIAIS ENGENHARIA DE SOFTWARE I':'TOPICOS ESPECIAIS ENGENHARIA DE SOFTWARE I',
#      90                 'SEMINÃRIO DE TECNOLOGIA DA INFORMAÃ‡ÃƒO':'SEMINARIO DE TECNOLOGIA DA INFORMACAO',
#      91                 'CONTABILIDADE AMBIENTAL':'CONTABILIDADE AMBIENTAL',
#      92                 'TESTE DE SOFTWARE':'TESTE DE SOFTWARE',
#      93                 'MARKETING DIGITAL':'MARKETING DIGITAL',
#      94                 'INTRODUÃ‡ÃƒO Ã€ INTERNET DAS COISAS':'INTRODUCAO A INTERNET DAS COISAS',
#      95                 'TÃ“PICOS ESPECIAIS EM MATEMÃTICA COMPUTACIONAL':'TOPICOS ESPECIAIS EM MATEMATICA COMPUTACIONAL',
#      96                 'METODOLOGIA CIENTÃFICA':'METODOLOGIA CIENTIFICA',
#      97                 'PRÃTICA DE LEITURA E PRODUCAO DE TEXTOS':'PRATICA DE LEITURA E PRODUCAO DE TEXTOS',
#      98                 'EMPREENDENDORISMO EM INFORMÃTICA':'EMPREENDENDORISMO EM INFORMATICA',
#      99                 'INTRODUÃ‡ÃƒO Ã€ INTERNET DAS COISAS':'INTRODUCAO A INTERNET DAS COISAS',
#     100                 'MATEMÃTICA BÃSICA':'MATEMATICA BASICA',
#     101                 'GEOGRAFIA FÃSICA DO BRASIL':'GEOGRAFIA FISICA DO BRASIL',
#     102                 'SEMINÃRIO DO TCC':'SEMINARIO DO TCC',
#     103                 'TÃ“PICOS AVANÃ‡ADOS EM PROGRAMACAO':'TOPICOS AVANCADOS EM PROGRAMACAO',
#     104                 'HISTÃ“RIA DO RIO GRANDE DO NORTE I':'HISTORIA DO RIO GRANDE DO NORTE I',
#     105                 'CONTABILIDADE BÃSICA I':'CONTABILIDADE BASICA I',
#     106                 'METODOLOGIA DO TRABALHO CIENTÃFICO':'METODOLOGIA DO TRABALHO CIENTIFICO',
#     107                 'SEMINÃRIO DE GEOGRAFIA DA AMÃ‰RICA LATINA':'SEMINARIO DE GEOGRAFIA DA AMERICA LATINA',
#     108                 'METODOLOGIA DA PESQUISA CIENTÃFICA':'METODOLOGIA DA PESQUISA CIENTIFICA',
#     109                 'TÃ“PICOS ESPECIAIS EM SISTEMAS DE INFORMAÃ‡ÃƒO II':'TOPICOS ESPECIAIS EM SISTEMAS DE INFORMACAO II',
#     110                 'MÃ‰TODOS E TÃ‰CNICAS DE PESQUISA CIENTÃFICA':'METODOS E TECNICAS DE PESQUISA CIENTIFICA',
#     111                 'METODOLOGIA DE ENSINO NA ÃREA DE DEFICIÃŠNCIA AUDITIVA':'METODOLOGIA DE ENSINO NA AREA DE DEFICIENCIA AUDITIVA',
#     112                 'HISTÃ“RIA MEDIEVAL I':'HISTORIA MEDIEVAL I',
#     113                 'CLIMATOLOGIA SISTEMÃTICA E REGIONAL':'CLIMATOLOGIA SISTEMITICA E REGIONAL',
#     114                 'LÃNGUA DE SINAIS BRASILEIRA  - LIBRAS':'LINGUA DE SINAIS BRASILEIRA  - LIBRAS',
#     115                 'HISTÃ“RIA DA AMÃ‰RICA I':'HISTORIA DA AMERICA I',
#     116                 'INTRODUÃ‡ÃƒO A PESQUISA HISTÃ“RICA':'INTRODUCAO A PESQUISA HISTORICA',
#     117                 'ECONOMIA POLÃTICA':'ECONOMIA POLITICA',
#     118                 'INTRODUÃ‡ÃƒO Ã€ LOGICA MATEMÃTICA':'INTRODUCAO A LOGICA MATEMATICA',
#     119                 }}, regex=True)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:8051, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    8048     else:
#    8049         to_replace, value = keys, values
# -> 8051     return self.replace(
#    8052         to_replace, value, inplace=inplace, limit=limit, regex=regex
#    8053     )
#    8054 else:
#    8055     # need a non-zero len on all axes
#    8056     if not self.size:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:8070, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    8062 if is_dict_like(value):  # {'A' : NA} -> {'A' : 0}
#    8063     # Note: Checking below for `in foo.keys()` instead of
#    8064     #  `in foo` is needed for when we have a Series and not dict
#    8065     mapping = {
#    8066         col: (to_replace[col], value[col])
#    8067         for col in to_replace.keys()
#    8068         if col in value.keys() and col in self
#    8069     }
# -> 8070     return self._replace_columnwise(mapping, inplace, regex)
#    8072 # {'A': NA} -> 0
#    8073 elif not is_list_like(value):
#    8074     # Operate column-wise
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:5847, in DataFrame._replace_columnwise(self, mapping, inplace, regex)
#    5844         ser = self.iloc[:, i]
#    5846         target, value = mapping[ax_value]
# -> 5847         newobj = ser.replace(target, value, regex=regex)
#    5849         res._iset_item(i, newobj, inplace=inplace)
#    5851 if inplace:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:8099, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    8094     if len(to_replace) != len(value):
#    8095         raise ValueError(
#    8096             f"Replacement lists must match in length. "
#    8097             f"Expecting {len(to_replace)} got {len(value)} "
#    8098         )
# -> 8099     new_data = self._mgr.replace_list(
#    8100         src_list=to_replace,
#    8101         dest_list=value,
#    8102         inplace=inplace,
#    8103         regex=regex,
#    8104     )
#    8106 elif to_replace is None:
#    8107     if not (
#    8108         is_re_compilable(regex)
#    8109         or is_list_like(regex)
#    8110         or is_dict_like(regex)
#    8111     ):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/base.py:278, in DataManager.replace_list(self, src_list, dest_list, inplace, regex)
#     275 """do a list replace"""
#     276 inplace = validate_bool_kwarg(inplace, "inplace")
# --> 278 bm = self.apply_with_block(
#     279     "replace_list",
#     280     src_list=src_list,
#     281     dest_list=dest_list,
#     282     inplace=inplace,
#     283     regex=regex,
#     284     using_cow=using_copy_on_write(),
#     285     already_warned=_AlreadyWarned(),
#     286 )
#     287 bm._consolidate_inplace()
#     288 return bm
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:1101, in Block.replace_list(self, src_list, dest_list, inplace, regex, using_cow, already_warned)
#    1098         already_warned.warned_already = True
#    1100 opt = get_option("future.no_silent_downcasting")
# -> 1101 for i, ((src, dest), mask) in enumerate(zip(pairs, masks)):
#    1102     convert = i == src_len  # only convert once at the end
#    1103     new_rb: list[Block] = []
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:1064, in <genexpr>(.0)
#    1056 if is_string_dtype(values.dtype):
#    1057     # Calculate the mask once, prior to the call of comp
#    1058     # in order to avoid repeating the same computations
#    1059     na_mask = ~isna(values)
#    1060     masks: Iterable[npt.NDArray[np.bool_]] = (
#    1061         extract_bool_array(
#    1062             cast(
#    1063                 ArrayLike,
# -> 1064                 compare_or_regex_search(
#    1065                     values, s[0], regex=regex, mask=na_mask
#    1066                 ),
#    1067             )
#    1068         )
#    1069         for s in pairs
#    1070     )
#    1071 else:
#    1072     # GH#38086 faster if we know we dont need to check for regex
#    1073     masks = (missing.mask_missing(values, s[0]) for s in pairs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/array_algos/replace.py:98, in compare_or_regex_search(a, b, regex, mask)
#      95 if isinstance(a, np.ndarray):
#      96     a = a[mask]
# ---> 98 result = op(a)
#     100 if isinstance(result, np.ndarray) and mask is not None:
#     101     # The shape of the mask can differ to that of the result
#     102     # since we may compare only a subset of a's or b's elements
#     103     tmp = np.zeros(mask.shape, dtype=np.bool_)
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2328, in vectorize.__call__(self, *args, **kwargs)
#    2325     vargs = [args[_i] for _i in inds]
#    2326     vargs.extend([kwargs[_n] for _n in names])
# -> 2328 return self._vectorize_call(func=func, args=vargs)
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2411, in vectorize._vectorize_call(self, func, args)
#    2408 # Convert args to object arrays first
#    2409 inputs = [asanyarray(a, dtype=object) for a in args]
# -> 2411 outputs = ufunc(*inputs)
#    2413 if ufunc.nout == 1:
#    2414     res = asanyarray(outputs, dtype=otypes[0])
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/array_algos/replace.py:89, in compare_or_regex_search.<locals>.<lambda>(x)
#      86     op = lambda x: operator.eq(x, b)
#      87 else:
#      88     op = np.vectorize(
# ---> 89         lambda x: bool(re.search(b, x))
#      90         if isinstance(x, str) and isinstance(b, (str, Pattern))
#      91         else False
#      92     )
#      94 # GH#32621 use mask to avoid comparing to NAs
#      95 if isinstance(a, np.ndarray):
#
# File /usr/lib/python3.10/re.py:200, in search(pattern, string, flags)
#     197 def search(pattern, string, flags=0):
#     198     """Scan through string looking for a match to the pattern, returning
#     199     a Match object, or None if no match was found."""
# --> 200     return _compile(pattern, flags).search(string)
#
# KeyboardInterrupt:

# %% [markdown]
# Exclusão dos dados ausentes na coluna media_final.

# %%
dados_turma_matricula_componente.dropna(subset=["media_final"], inplace=True)
dados_turma_matricula_componente
# Out:
#        id_turma codigo_turma      siape  matricula_docente_externo  \
# 53645  57678929           01  3766151.0                        NaN
# 60148  57708933           01  2364748.0                        NaN
# 58456  57699493           01  3766151.0                        NaN
# 48560  57662868           01  1100806.0                        NaN
# 39686  57620123           03  1209872.0                        NaN
# ...         ...          ...        ...                        ...
# 9173    1178438           01  1804944.0                        NaN
# 10327   1178453           01  2766151.0                        NaN
# 9021    1178437           01  1687186.0                        NaN
# 9174    1178438           01  1804944.0                        NaN
# 10328   1178453           01  2766151.0                        NaN
#
#                               observacao  id_componente_curricular  \
# 53645                                NaN                     70811
# 60148                                NaN                     62802
# 58456  Todas as aulas serão presenciais.                     70811
# 48560                                NaN                     71950
# 39686                                NaN                     62768
# ...                                  ...                       ...
# 9173                                 NaN                   2037001
# 10327                                NaN                   2037004
# 9021                                 NaN                   2037000
# 9174                                 NaN                   2037001
# 10328                                NaN                   2037004
#
#        ch_dedicada_periodo nivel_ensino  campus_turma  \
# 53645                   60    GRADUAÇÃO  Campus Caicó
# 60148                   60    GRADUAÇÃO  Campus Caicó
# 58456                   60    GRADUAÇÃO  Campus Caicó
# 48560                   60    GRADUAÇÃO  Campus Caicó
# 39686                   60    GRADUAÇÃO  Campus Caicó
# ...                    ...          ...           ...
# 9173                    60    GRADUAÇÃO  Campus Caicó
# 10327                   60    GRADUAÇÃO  Campus Caicó
# 9021                    90    GRADUAÇÃO  Campus Caicó
# 9174                    60    GRADUAÇÃO  Campus Caicó
# 10328                   60    GRADUAÇÃO  Campus Caicó
#
#                                                local  ...  \
# 53645                         Online - Ensino Remoto  ...
# 60148  Laboratório II (John von Neumann) - Bloco BSI  ...
# 58456                                       Sala B04  ...
# 48560                                         Online  ...
# 39686                                        Lab. II  ...
# ...                                              ...  ...
# 9173                                            B-09  ...
# 10327                                           B-09  ...
# 9021                                 LAB.ALAN TURING  ...
# 9174                                            B-09  ...
# 10328                                           B-09  ...
#
#                                                   ementa  bibliografia  \
# 53645  Estudo dos conceitos de inovação, seus reflexo...           NaN
# 60148  Logística e problemas de otimização. Formulaçã...           NaN
# 58456  Estudo dos conceitos de inovação, seus reflexo...           NaN
# 48560  O conceito de Marketing. Conceito e evolução d...           NaN
# 39686  Conceituação de computação móvel, ubíqua e per...           NaN
# ...                                                  ...           ...
# 9173   Definição e origem do termo informática. Eleme...           NaN
# 10327  O conceito de Administração. A evolução das es...           NaN
# 9021   Algoritmos, programas e linguagens de programa...           NaN
# 9174   Definição e origem do termo informática. Eleme...           NaN
# 10328  O conceito de Administração. A evolução das es...           NaN
#
#                                                objetivos  \
# 53645  Estudo dos conceitos de inovação, seus reflexo...
# 60148  Apresentar aos alunos da área de Computação e ...
# 58456  Estudo dos conceitos de inovação, seus reflexo...
# 48560  Apresentar os conceitos fundamentais e prática...
# 39686  1. Apresentar os principais conceitos relativo...
# ...                                                  ...
# 9173   \r\n\tEntender o hardware de um sistema compu...
# 10327  1. Objetivo Geral\r\nDesenvolver o senso críti...
# 9021   Oferecer aos alunos uma visão geral sobre algo...
# 9174   \r\n\tEntender o hardware de um sistema compu...
# 10328  1. Objetivo Geral\r\nDesenvolver o senso críti...
#
#                                                 conteudo  \
# 53645  Estudo dos conceitos de inovação, seus reflexo...
# 60148  1. Introdução à Logística e aos problemas de o...
# 58456  Estudo dos conceitos de inovação, seus reflexo...
# 48560  1ª UNIDADE\r\n1. Visão geral de Marketing (con...
# 39686  1. DISPOSITIVOS MÓVEIS: Conceitos, tipos e car...
# ...                                                  ...
# 9173   \r\n\tHistórico\r\n\tTecnologias e aplicaçõe...
# 10327  1. ABORDAGEM CLÁSSICA DA ADMINISTRAÇÃO\r\n Te...
# 9021   \r\n\r\n1.\tUnidade I\r\n1.1.\tNoções de lógic...
# 9174   \r\n\tHistórico\r\n\tTecnologias e aplicaçõe...
# 10328  1. ABORDAGEM CLÁSSICA DA ADMINISTRAÇÃO\r\n Te...
#
#                                 competencias_habilidades  \
# 53645                                                NaN
# 60148                                                NaN
# 58456                                                NaN
# 48560                                                NaN
# 39686                                                NaN
# ...                                                  ...
# 9173   \r\nAo final do componente curricular o aluno ...
# 10327  Espera-se que o aluno desenvolva o  embasament...
# 9021   Ao final da disciplina espera-se que o aluno s...
# 9174   \r\nAo final do componente curricular o aluno ...
# 10328  Espera-se que o aluno desenvolva o  embasament...
#
#                                              referencias  ano_programa  \
# 53645                                                NaN        2023.0
# 60148                                                NaN        2022.0
# 58456                                                NaN        2023.0
# 48560                                                NaN        2023.0
# 39686                                                NaN        2021.0
# ...                                                  ...           ...
# 9173   \r\nCaro Usuário,\r\n\r\nEstas informações ser...        2013.0
# 10327  Bibliografia Básica\r\nCHIAVENATO, Idalberto. ...        2010.0
# 9021   ü\tForbellone, André. Lógica de Programação. A...        2010.0
# 9174   \r\nCaro Usuário,\r\n\r\nEstas informações ser...        2013.0
# 10328  Bibliografia Básica\r\nCHIAVENATO, Idalberto. ...        2010.0
#
#       periodo_programa  modalidade        curso_componente
# 53645              2.0  Presencial                     NaN
# 60148              2.0  Presencial                     NaN
# 58456              2.0  Presencial                     NaN
# 48560              1.0  Presencial                     NaN
# 39686              2.0  Presencial                     NaN
# ...                ...         ...                     ...
# 9173               2.0  Presencial  SISTEMAS DE INFORMAÇÃO
# 10327              1.0  Presencial                     NaN
# 9021               2.0  Presencial                     NaN
# 9174               2.0  Presencial  SISTEMAS DE INFORMAÇÃO
# 10328              1.0  Presencial                     NaN
#
# [47924 rows x 59 columns]

# %% [markdown]
# Contando o número de valores ausentes em cada coluna do DataFrame.

# %%
dados_turma_matricula_componente.isnull().sum()
# Out:
# id_turma                         0
# codigo_turma                     0
# siape                          489
# matricula_docente_externo    47435
# observacao                   45305
# id_componente_curricular         0
# ch_dedicada_periodo              0
# nivel_ensino                     0
# campus_turma                     0
# local                            0
# ano                              0
# periodo                          0
# data_inicio                      0
# data_fim                         0
# descricao_horario               96
# total_solicitacoes             348
# capacidade_aluno                 0
# tipo                             0
# distancia                        0
# data_consolidacao                0
# agrupadora                       0
# id_turma_agrupadora          47924
# qtd_aulas_lancadas           14376
# situacao_turma                   0
# convenio                     47924
# modalidade_participantes         0
# discente                         0
# unidade                          3
# media_final                      0
# descricao                        0
# id_componente                    0
# tipo_componente                  0
# codigo                           0
# nivel                            0
# nome                             0
# unidade_responsavel              0
# ch_teorico                       0
# ch_pratico                       0
# ch_estagio                       0
# ch_total                         0
# ch_dedicada_docente              0
# ch_ead                           0
# cr_max_ead                       0
# permite_horario_flexivel         0
# qtd_unidades                     0
# procedimentos_avaliacao      35865
# equivalencia                  2690
# pre_requisito                25141
# co_requisito                 47894
# ementa                           0
# bibliografia                 47924
# objetivos                       45
# conteudo                        45
# competencias_habilidades     28469
# referencias                  35865
# ano_programa                    45
# periodo_programa                45
# modalidade                       0
# curso_componente             41795
# dtype: int64

# %% [markdown]
# Para salvar o DataFrame no formato CSV com a separação por ';' e garantir que os dados numéricos estejam no formato correto

# %%
dados_turma_matricula_componente.to_csv('turma-matricula-componente.csv', index=False, sep=';', quoting=csv.QUOTE_NONNUMERIC)
